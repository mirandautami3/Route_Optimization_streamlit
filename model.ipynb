# %%
import pandas as pd

# Load data dari CSV
df = pd.read_csv('surabaya_routes.csv')

# Menampilkan 5 baris pertama untuk melihat struktur data
print(df.head())
# Out:
#        Start_Name  Start_Lat   Start_Lon                 End_Name   End_Lat  \
# 0  Stasiun Gubeng  -7.257472  112.752088          Tunjungan Plaza -7.266735
# 1  Stasiun Gubeng  -7.257472  112.752088  Kebun Binatang Surabaya -7.290215
# 2  Stasiun Gubeng  -7.257472  112.752088     Surabaya Town Square -7.290116
# 3  Stasiun Gubeng  -7.257472  112.752088          Grand City Mall -7.261414
# 4  Stasiun Gubeng  -7.257472  112.752088      Terminal Bungurasih -7.345473
#
#       End_Lon  Distance_km  Duration_min
# 0  112.736115       4.5955      6.468333
# 1  112.735337       5.7728      6.386667
# 2  112.734558       5.8817      6.803333
# 3  112.751639       0.8897      1.513333
# 4  112.742177      14.0382     15.553333

# %%
import numpy as np
import random

# Menghitung jumlah state dan action
state_space = len(df)
action_space = len(df)

# Inisialisasi Q-table
Q_table = np.zeros((state_space, action_space))

# Hyperparameters
learning_rate = 0.1
discount_factor = 0.9
epsilon = 0.1  # Eksplorasi vs Eksploitasi

# Fungsi untuk memilih aksi menggunakan epsilon-greedy
def choose_action(state):
    if random.uniform(0, 1) < epsilon:
        return random.choice(range(action_space))  # Eksplorasi
    else:
        return np.argmax(Q_table[state])  # Eksploitasi

# Fungsi untuk menghitung reward
def calculate_reward(action):
    distance = df.iloc[action]['Distance_km']
    duration = df.iloc[action]['Duration_min']
    return - (distance + duration)  # Reward negatif untuk jarak dan durasi

# Training Q-Learning
for episode in range(1000):  # Jumlah episode (latihan)
    state = random.randint(0, state_space - 1)  # Pilih state acak sebagai titik mulai
    done = False

    while not done:
        action = choose_action(state)
        reward = calculate_reward(action)
        next_state = action  # Pindah ke state berikutnya setelah aksi

        # Pembaruan Q-table
        Q_table[state, action] = Q_table[state, action] + learning_rate * (reward + discount_factor * np.max(Q_table[next_state]) - Q_table[state, action])
        
        state = next_state
        done = True  # Setiap episode selesai setelah satu langkah

# Melihat hasil Q-table setelah training
print("Q-table:")
print(Q_table)
# Out:
# Q-table:
# [[-1.10638333 -1.21594667 -1.26850333 ...  0.          0.
#    0.        ]
#  [-1.10638333 -1.21594667 -1.26850333 ...  0.          0.
#    0.        ]
#  [-1.10638333 -1.21594667 -1.26850333 ...  0.          0.
#    0.        ]
#  ...
#  [-1.10638333 -1.21594667 -2.41015633 ...  0.          0.
#   -2.38285   ]
#  [-1.10638333 -1.21594667 -1.26850333 ...  0.          0.
#    0.        ]
#  [-2.10212833 -1.21594667 -1.26850333 ...  0.          0.
#    0.        ]]

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense
from sklearn.preprocessing import MinMaxScaler
import numpy as np

# Memilih fitur Distance_km untuk input (X) dan Duration_min untuk output (y)
X = df[['Distance_km']].values
y = df['Duration_min'].values

# Normalisasi data untuk LSTM
scaler_X = MinMaxScaler(feature_range=(0, 1))
scaler_y = MinMaxScaler(feature_range=(0, 1))

X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y.reshape(-1, 1))

# Reshaping untuk input LSTM: [samples, timesteps, features]
X_scaled = X_scaled.reshape((X_scaled.shape[0], 1, X_scaled.shape[1]))

# Membuat model LSTM
model = Sequential()
model.add(LSTM(units=50, activation='relu', input_shape=(X_scaled.shape[1], X_scaled.shape[2])))
model.add(Dense(1))  # Output: prediksi waktu tempuh
model.compile(optimizer='adam', loss='mean_squared_error')

# Melatih model LSTM
model.fit(X_scaled, y_scaled, epochs=100, batch_size=32)

# Prediksi waktu tempuh berdasarkan input Distance_km
predicted_time = model.predict(X_scaled)
predicted_time = scaler_y.inverse_transform(predicted_time)

# Menampilkan hasil prediksi
print("Prediksi Waktu Tempuh (Durasi):")
print(predicted_time[:5])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.24453
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2487
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 988us/step - loss: 0.2346
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2185
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2134
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1999
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1847
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1968
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step - loss: 0.1853
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1803
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1770
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1678
# Epoch 13/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.1543
# Epoch 14/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1655
# Epoch 15/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1532
# Epoch 16/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1390
# Epoch 17/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1321
# Epoch 18/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1181
# Epoch 19/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1147
# Epoch 20/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1186
# Epoch 21/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 969us/step - loss: 0.1057
# Epoch 22/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 932us/step - loss: 0.1013
# Epoch 23/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0951
# Epoch 24/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1003
# Epoch 25/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0800
# Epoch 26/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0763
# Epoch 27/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0828
# Epoch 28/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0740
# Epoch 29/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0735
# Epoch 30/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0670
# Epoch 31/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0609
# Epoch 32/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0575
# Epoch 33/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 975us/step - loss: 0.0511
# Epoch 34/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 887us/step - loss: 0.0465
# Epoch 35/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0474
# Epoch 36/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0457
# Epoch 37/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0383
# Epoch 38/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0362
# Epoch 39/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0366
# Epoch 40/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 919us/step - loss: 0.0325
# Epoch 41/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0295
# Epoch 42/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0249
# Epoch 43/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0292
# Epoch 44/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0276
# Epoch 45/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0249
# Epoch 46/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0236
# Epoch 47/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0230
# Epoch 48/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0211
# Epoch 49/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0205
# Epoch 50/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0196
# Epoch 51/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step - loss: 0.0198
# Epoch 52/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0199
# Epoch 53/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step - loss: 0.0194
# Epoch 54/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0194
# Epoch 55/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0171
# Epoch 56/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 875us/step - loss: 0.0191
# Epoch 57/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step - loss: 0.0187
# Epoch 58/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0170
# Epoch 59/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 883us/step - loss: 0.0196
# Epoch 60/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 827us/step - loss: 0.0191
# Epoch 61/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0167
# Epoch 62/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 931us/step - loss: 0.0168
# Epoch 63/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step - loss: 0.0173
# Epoch 64/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0171
# Epoch 65/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 857us/step - loss: 0.0157
# Epoch 66/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0172
# Epoch 67/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0176
# Epoch 68/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0186
# Epoch 69/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0163
# Epoch 70/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0151
# Epoch 71/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0172
# Epoch 72/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0165
# Epoch 73/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0156
# Epoch 74/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0158
# Epoch 75/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0147
# Epoch 76/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0175
# Epoch 77/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0158
# Epoch 78/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 936us/step - loss: 0.0159
# Epoch 79/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 932us/step - loss: 0.0143
# Epoch 80/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step - loss: 0.0138
# Epoch 81/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 906us/step - loss: 0.0150
# Epoch 82/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 866us/step - loss: 0.0151
# Epoch 83/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 957us/step - loss: 0.0141
# Epoch 84/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0148
# Epoch 85/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 813us/step - loss: 0.0161
# Epoch 86/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 880us/step - loss: 0.0159
# Epoch 87/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 835us/step - loss: 0.0142
# Epoch 88/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0149
# Epoch 89/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0141
# Epoch 90/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 916us/step - loss: 0.0140
# Epoch 91/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0130
# Epoch 92/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0124
# Epoch 93/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0146
# Epoch 94/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 857us/step - loss: 0.0137
# Epoch 95/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 948us/step - loss: 0.0126
# Epoch 96/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0131
# Epoch 97/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0129
# Epoch 98/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0122
# Epoch 99/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0130
# Epoch 100/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 842us/step - loss: 0.0131
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Prediksi Waktu Tempuh (Durasi):
# [[ 9.730769]
#  [10.39581 ]
#  [10.457993]
#  [ 7.722953]
#  [15.439824]]

# %%
# Import Libraries
import numpy as np
import random
from keras.models import Sequential
from keras.layers import LSTM, Dense
from sklearn.preprocessing import MinMaxScaler

# Simulasi data rute
df = pd.read_csv('surabaya_routes_clean.csv')

# Normalisasi Data
scaler_X = MinMaxScaler(feature_range=(0, 1))
scaler_y = MinMaxScaler(feature_range=(0, 1))

X = df[['Distance_km']].values
y = df['Duration_min'].values

X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y.reshape(-1, 1))

# Reshape data untuk LSTM (samples, timesteps, features)
X_scaled = X_scaled.reshape((X_scaled.shape[0], 1, X_scaled.shape[1]))

# LSTM Model untuk memprediksi waktu tempuh
model_lstm = Sequential()
model_lstm.add(LSTM(units=50, activation='relu', input_shape=(X_scaled.shape[1], X_scaled.shape[2])))
model_lstm.add(Dense(1))  # Output: prediksi waktu tempuh
model_lstm.compile(optimizer='adam', loss='mean_squared_error')

# Melatih Model LSTM
model_lstm.fit(X_scaled, y_scaled, epochs=100, batch_size=32)

# Prediksi waktu tempuh menggunakan LSTM
predicted_time = model_lstm.predict(X_scaled)
predicted_time = scaler_y.inverse_transform(predicted_time)

# Definisikan Q-learning untuk optimasi rute

# Menghitung jumlah state dan action
state_space = len(df)
action_space = len(df)

# Inisialisasi Q-table
Q_table = np.zeros((state_space, action_space))

# Hyperparameters untuk Q-learning
learning_rate = 0.1
discount_factor = 0.9
epsilon = 0.1  # Eksplorasi vs Eksploitasi

# Fungsi untuk memilih aksi menggunakan epsilon-greedy
def choose_action(state):
    if random.uniform(0, 1) < epsilon:
        return random.choice(range(action_space))  # Eksplorasi
    else:
        return np.argmax(Q_table[state])  # Eksploitasi

# Fungsi untuk menghitung reward
def calculate_reward(action):
    # Menggunakan prediksi waktu tempuh dari LSTM sebagai reward
    distance = df.iloc[action]['Distance_km']
    duration_predicted = predicted_time[action][0]  # Menggunakan hasil prediksi LSTM
    return - (distance + duration_predicted)  # Reward negatif agar semakin kecil waktu dan jarak semakin tinggi reward

# Training Q-learning
for episode in range(1000):  # Jumlah episode (latihan)
    state = random.randint(0, state_space - 1)  # Pilih state acak sebagai titik mulai
    done = False

    while not done:
        action = choose_action(state)
        reward = calculate_reward(action)
        next_state = action  # Pindah ke state berikutnya setelah aksi

        # Pembaruan Q-table
        Q_table[state, action] = Q_table[state, action] + learning_rate * (reward + discount_factor * np.max(Q_table[next_state]) - Q_table[state, action])
        
        state = next_state
        done = True  # Setiap episode selesai setelah satu langkah

# Melihat hasil Q-table setelah training
print("Q-table:")
print(Q_table)

# Menggunakan Q-table untuk memilih rute terbaik
best_route = np.argmax(Q_table[0])  # Memilih aksi terbaik dari state 0 (mulai dari titik awal)
print(f"Rute terbaik yang dipilih berdasarkan Q-learning: Rute {best_route}")
# Out:
# Epoch 1/100
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2450
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2368
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2378
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2350
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 815us/step - loss: 0.2137
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2244
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2022
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2083
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1953
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1814
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1777
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1847
# Epoch 13/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1838
# Epoch 14/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1751
# Epoch 15/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1604
# Epoch 16/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1590
# Epoch 17/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1602
# Epoch 18/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - loss: 0.1515
# Epoch 19/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1446
# Epoch 20/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1501
# Epoch 21/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1374
# Epoch 22/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1268
# Epoch 23/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1344
# Epoch 24/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1263
# Epoch 25/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1093
# Epoch 26/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 878us/step - loss: 0.1198
# Epoch 27/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1040
# Epoch 28/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 936us/step - loss: 0.1032
# Epoch 29/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0904
# Epoch 30/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 993us/step - loss: 0.0998
# Epoch 31/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0761
# Epoch 32/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 954us/step - loss: 0.0869
# Epoch 33/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 785us/step - loss: 0.0805
# Epoch 34/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0789
# Epoch 35/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0704
# Epoch 36/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0611
# Epoch 37/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step - loss: 0.0620
# Epoch 38/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 871us/step - loss: 0.0534
# Epoch 39/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0607
# Epoch 40/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0548
# Epoch 41/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0479
# Epoch 42/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.05041
# Epoch 43/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0446
# Epoch 44/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 961us/step - loss: 0.0375
# Epoch 45/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 967us/step - loss: 0.0398
# Epoch 46/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - loss: 0.0358
# Epoch 47/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0354
# Epoch 48/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0329
# Epoch 49/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0296
# Epoch 50/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0297
# Epoch 51/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0297
# Epoch 52/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - loss: 0.0288
# Epoch 53/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0256
# Epoch 54/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0257
# Epoch 55/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0246
# Epoch 56/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0229
# Epoch 57/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0231
# Epoch 58/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0213
# Epoch 59/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0216
# Epoch 60/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step - loss: 0.0208
# Epoch 61/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0214
# Epoch 62/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 895us/step - loss: 0.0213
# Epoch 63/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0194
# Epoch 64/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 982us/step - loss: 0.0193
# Epoch 65/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 937us/step - loss: 0.0203
# Epoch 66/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0196
# Epoch 67/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0205
# Epoch 68/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 969us/step - loss: 0.0196
# Epoch 69/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0204
# Epoch 70/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0208
# Epoch 71/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0207
# Epoch 72/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 954us/step - loss: 0.0203
# Epoch 73/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0182
# Epoch 74/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step - loss: 0.0193
# Epoch 75/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0182
# Epoch 76/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0202
# Epoch 77/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0171
# Epoch 78/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0168
# Epoch 79/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0173
# Epoch 80/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0186
# Epoch 81/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0176
# Epoch 82/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0189
# Epoch 83/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0191
# Epoch 84/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0177
# Epoch 85/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0173
# Epoch 86/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0174
# Epoch 87/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0173
# Epoch 88/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0160
# Epoch 89/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 855us/step - loss: 0.0161
# Epoch 90/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0164
# Epoch 91/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0176
# Epoch 92/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0149
# Epoch 93/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0152
# Epoch 94/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0153
# Epoch 95/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0163
# Epoch 96/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 920us/step - loss: 0.0153
# Epoch 97/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0157
# Epoch 98/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0156
# Epoch 99/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0157
# Epoch 100/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 963us/step - loss: 0.0149
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Q-table:
# [[-1.48287106 -1.65986905 -1.67629799 ...  0.          0.
#    0.        ]
#  [-1.48287106 -1.65986905 -1.67629799 ...  0.          0.
#    0.        ]
#  [-1.48287106 -1.65986905 -1.67629799 ...  0.          0.
#    0.        ]
#  ...
#  [-1.48287106 -1.65986905 -1.67629799 ...  0.          0.
#    0.        ]
#  [-1.48287106 -1.65986905 -1.67629799 ...  0.          0.
#    0.        ]
#  [-1.48287106 -1.65986905 -1.67629799 ...  0.          0.
#    0.        ]]
# Rute terbaik yang dipilih berdasarkan Q-learning: Rute 9
